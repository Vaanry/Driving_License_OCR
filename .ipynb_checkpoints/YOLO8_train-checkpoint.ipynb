# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# Train the model with Roboflow dataset
results = model.train(data='driving license.v1i.yolov8\\data.yaml', epochs=100)
# Out:
# New https://pypi.org/project/ultralytics/8.1.8 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.51  Python-3.9.18 torch-2.1.2+cpu CPU
# ...

# %%
from ultralytics import YOLO

# Load a model
new_model = YOLO(r'runs\detect\train10\weights\last.pt')

# Train the model additionally with custom dataset
new_results = new_model.train(data=r'\dataset_05.02.24\data.yaml', epochs=100)
# Out:
# New https://pypi.org/project/ultralytics/8.1.9 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.51  Python-3.9.18 torch-2.1.2+cpu CPU
# ...
